# %%
l=[['','',''],['','',''],['','','']]

# %%
 def p (l):   
    for i in l :
        print (i)

# %%
def update (l,sympol):
    print('this the role of'+'  '+sympol) 
    a=0
    while a  not in [1,2,3]:
        a=int(input ('please inter in which row do you want your sympol your sympol must be 1 2 3'))
    b=0
    while b  not in [1,2,3]:
        b=int(input ('please inter in which coulmn do you want your sympol your sympol must be 1 2 3'))
    print (a)
    print (b)
    if l[a-1][b-1]== '':
        l[a-1][b-1]=sympol
    else:
        print('this position is taken repeat  the try again')
        update (l,sympol)

# %%
def check_win(l):
    global q
    q=''
    if l[0][0]==l[1][1]and l[1][1]==l[2][2]and l[0][0]in ['x','o'] :
        q=(l[0][0]+' '+'is the winner')
        print(q)
    elif l[0][2]==l[1][1]and l[1][1]==l[2][0]and l[0][2]in ['x','o']:
        q=(l[0][2]+' '+'is the winner')
        print(q)
    else:
            for i in [0,1,2]:
                if l[i][0]==l[i][1]and l[i][1]==l[i][2]and l[i][0]in ['x','o']:
                    q =(l[i][0]+' '+'is the winner')
                    print(q)
                    break
                elif (l[0][i]==l[1][i])and (l [0][i]==l[2][i])and l[0][i]in ['x','o']:
                    q=(l[i][0]+' '+'is the winner')
                    print(q)
                    break
    if q == '':
        pass

# %%
def check_tie(l):
    global w
    w=0
    for i in l:
        if '' in i:
            break
        else:
            w=w+1
    if w==3:
        print ('Tie')

# %%
l=[['','',''],['','',''],['','','']]
while True:
    for i in ['x','o']:
        print ('this is the'+' '+i+' role')
        p(l)
        update (l,i)
        p(l)
        check_win(l)
        if q !='':
            break
        else:
            check_tie(l)
            if w==3:
                break
    if q !='':
            break
    if w==3:
                break
# Out:
# this is the x role
# ['', '', '']
# ['', '', '']
# ['', '', '']
# this the role of  x
# please inter in which row do you want your sympol your sympol must be 1 2 31
# please inter in which coulmn do you want your sympol your sympol must be 1 2 31
# 1
# 1
# ['x', '', '']
# ['', '', '']
# ['', '', '']
# this is the o role
# ['x', '', '']
# ['', '', '']
# ['', '', '']
# this the role of  o
# please inter in which row do you want your sympol your sympol must be 1 2 31
# please inter in which coulmn do you want your sympol your sympol must be 1 2 32
# 1
# 2
# ['x', 'o', '']
# ['', '', '']
# ['', '', '']
# this is the x role
# ['x', 'o', '']
# ['', '', '']
# ['', '', '']
# this the role of  x
# please inter in which row do you want your sympol your sympol must be 1 2 32
# please inter in which coulmn do you want your sympol your sympol must be 1 2 32
# 2
# 2
# ['x', 'o', '']
# ['', 'x', '']
# ['', '', '']
# this is the o role
# ['x', 'o', '']
# ['', 'x', '']
# ['', '', '']
# ...
